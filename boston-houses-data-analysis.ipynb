# %% [markdown]
# ## Descripción del Conjunto de Datos de Boston Housing (Business understanding)
#
# El conjunto de datos de Boston Housing contiene información sobre diversas características de viviendas en diferentes áreas de Boston. Este conjunto de datos es ampliamente utilizado para tareas de regresión y análisis de precios de viviendas. A continuación se presenta un resumen de las características y estadísticas básicas del conjunto de datos:
#
# Características del Conjunto de Datos:
#
# CRIM: Tasa de criminalidad per cápita por ciudad.
#
# ZN: Proporción de terrenos residenciales zonificados para lotes de más de 25,000 pies cuadrados.
#
# INDUS: Proporción de acres comerciales no minoristas por ciudad.
#
# CHAS: Variable ficticia del río Charles (1 si el tramo limita con el río; 0 en caso contrario).
#
# NOX: Concentración de óxidos nítricos (partes por 10 millones).
#
# RM: Número medio de habitaciones por vivienda.
#
# AGE: Proporción de unidades ocupadas por sus propietarios construidas antes de 1940.
#
# DIS: Distancias ponderadas a cinco centros de empleo de Boston.
#
# RAD: Índice de accesibilidad a carreteras radiales.
#
# TAX: Tasa de impuesto a la propiedad por cada $10,000.
#
# PTRATIO: Proporción alumno-maestro por ciudad.
#
# B: 1000(𝐵𝑘−0.63)21000(Bk−0.63)2 donde 𝐵𝑘Bk es la proporción de personas de ascendencia afroamericana por ciudad.
#
# LSTAT: Porcentaje de población de estatus socioeconómico bajo.
#
# target: Valor medio de las viviendas ocupadas por sus propietarios en $1000's.

# %%
from modules.data_generator import Data_Module
from modules.visualization import Visualizer
from modules.analysis import Analysis

data = Data_Module('./data/boston_housing.csv', target_column='target')
visualizer = Visualizer()
analysis = Analysis()
visualizer = Visualizer()
data.load_data()

# %%
data.X_origin.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
data.y_target.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: target, dtype: float64

# %%
data.X_origin.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data.y_target.describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: target, dtype: float64

# %%
data.X_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
data.y_target.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 506 entries, 0 to 505
# Series name: target
# Non-Null Count  Dtype
# --------------  -----
# 506 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# ### Estadísticas Básicas:
#
# El conjunto de datos contiene 506 entradas y 14 columnas.
#
# No hay valores nulos en ninguna de las columnas.
#
# La media de la tasa de criminalidad (CRIM) es aproximadamente 3.61.
#
# La media del número medio de habitaciones por vivienda (RM) es aproximadamente 6.28.
#
# La media del valor medio de las viviendas (target) es aproximadamente $22,530.
#
# Información Adicional:
#
# La variable CHAS es una variable categórica que indica si una vivienda está cerca del río Charles.
#
# Las variables CRIM, ZN, INDUS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B y LSTAT son variables numéricas que describen diversas características de las viviendas y sus alrededores.
#
# La variable target es la variable objetivo que representa el valor medio de las viviendas.

# %% [markdown]
# Preparación de datos
#
# Verificación de la existencia de datos perdidos: Este paso consiste en revisar si hay valores nulos en el conjunto de datos. Esto nos permite identificar qué columnas tienen datos faltantes y en qué cantidad.
#
# División de las observaciones con valores perdidos: En este paso, se separan las observaciones que contienen valores perdidos del resto del conjunto de datos. Estas observaciones se guardan en una copia del DataFrame para su análisis posterior, permitiendo un manejo más eficiente y organizado de los datos faltantes.

# %%
data.check_missing_data()
# Out:
# (CRIM       0
#  ZN         0
#  INDUS      0
#  CHAS       0
#  NOX        0
#  RM         0
#  AGE        0
#  DIS        0
#  RAD        0
#  TAX        0
#  PTRATIO    0
#  B          0
#  LSTAT      0
#  dtype: int64,
#  0)

# %%
data.prepare_data()
data.preprocess_data()

# %% [markdown]
# Resumen
#
# No hay datos perdidos: Todas las columnas tienen 506 valores no nulos.
#
# No hay observaciones con datos perdidos: El DataFrame df_missing está vacío.
#
# Eliminación de duplicados: No se encontraron duplicados en el conjunto de datos.

# %%
visualizer.plot_distributions(data.get_data(), data.get_numeric_columns())
# Out:
# <module 'matplotlib.pyplot' from '/home/armsjs/anaconda3/envs/DataSciencePortfolio/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
# Calcular la matriz de correlación
correlation_matrix = data.calculate_correlation_matrix()

# Plotear la matriz de correlación
visualizer.plot_correlation_matrix(correlation_matrix)

# %% [markdown]
# La matriz de correlación revela relaciones significativas entre las variables. LSTAT (porcentaje de población de estatus socioeconómico bajo) y RM (número medio de habitaciones por vivienda) muestran fuertes correlaciones con la variable objetivo target, -0.74 y 0.70 respectivamente. Estas relaciones sugieren que más habitaciones en una vivienda están asociadas con un mayor valor medio, mientras que un mayor porcentaje de población de estatus socioeconómico bajo está asociado con menores valores de vivienda.
#
# Otras correlaciones notables incluyen la fuerte relación entre TAX (tasa de impuesto a la propiedad) y RAD (índice de accesibilidad a carreteras radiales) con 0.91, lo que indica posible multicolinealidad.

# %%
# Crear nuevo conjunto de datos
data.add_dataset(name='no_high_corr', dataframe=data.df)

# Configurar el límite de correlación
data.correlation_threshold = 0.6

# Eliminar al menos una característica altamente correlacionada
data.remove_highly_correlated_features(dataset_name='no_high_corr', exceptions=['target', 'RAD', 'INDUS', 'DIS', 'LSTAT', 'RM'])

# Calcular la matriz de correlación
correlation_matrix = data.calculate_correlation_matrix(dataset_name='no_high_corr')

# Plotear la matriz de correlación
visualizer.plot_correlation_matrix(correlation_matrix)
# Out:
# ['NOX', 'AGE', 'TAX']

# %% [markdown]
# La nueva tabla de correlación conserva a las variables 'RAD', 'INDUS', 'DIS', 'LSTAT', 'RM', seleccionadas para el análisis de entre las distintas correlaciones. Las variables removidas fueron 'NOX', 'AGE', 'TAX'. A continuación se generarán modelos para el conjutno de datos completo y el conjunto de datos sin 'NOX', 'AGE' ni 'TAX'.

# %%
# Configurar las máximas iteraciones
analysis.lasso_max_iter = 20000
analysis.ridge_max_iter = 20000

# Preprocesar los datos sin las características eliminadas
data.preprocess_data(dataset_name='no_high_corr')
X_train, X_test, y_train, y_test = data.split_data()
analysis.train_models(X_train, y_train)
linear_mse, linear_r2 = analysis.evaluate_model(analysis.linear_model, X_test, y_test)
ridge_mse, ridge_r2 = analysis.evaluate_model(analysis.ridge_model, X_test, y_test)
lasso_mse, lasso_r2 = analysis.evaluate_model(analysis.lasso_model, X_test, y_test)

print('Linear Regression - MSE:', linear_mse, ', R2:', linear_r2)
print('Ridge Regression - MSE:', ridge_mse, ', R2:', ridge_r2)
print('Lasso Regression - MSE:', lasso_mse, ', R2:', lasso_r2)
# Out:
# Linear Regression - MSE: 17.57146651363775 , R2: 0.7603905627611921
# Ridge Regression - MSE: 17.79754267090994 , R2: 0.7573077249812573
# Lasso Regression - MSE: 15.166172568051776 , R2: 0.7931898244647306

# %%
#Procesar los datos completos
data.preprocess_data()
X_train, X_test, y_train, y_test = data.split_data()
analysis.train_models(X_train, y_train)
linear_mse, linear_r2 = analysis.evaluate_model(analysis.linear_model, X_test, y_test)
ridge_mse, ridge_r2 = analysis.evaluate_model(analysis.ridge_model, X_test, y_test)
lasso_mse, lasso_r2 = analysis.evaluate_model(analysis.lasso_model, X_test, y_test)

print('Linear Regression - MSE:', linear_mse, ', R2:', linear_r2)
print('Ridge Regression - MSE:', ridge_mse, ', R2:', ridge_r2)
print('Lasso Regression - MSE:', lasso_mse, ', R2:', lasso_r2)
# Out:
# Linear Regression - MSE: 14.183558215941154 , R2: 0.8065890288936419
# Ridge Regression - MSE: 14.142093755327776 , R2: 0.8071544498882567
# Lasso Regression - MSE: 12.77857788983479 , R2: 0.8257477340027836

# %% [markdown]
# Los resultados muestran que los modelos de regresión (Linear, Ridge, Lasso) tienen mejor desempeño con el conjunto de datos completo. Lasso Regression destaca, con un MSE de 12.78 y un R² de 0.83, indicando que maneja bien las relaciones entre las variables y el objetivo. Al eliminar variables altamente correlacionadas, el rendimiento disminuye en todos los modelos, sugiriendo que las variables eliminadas aportaban información valiosa. En el conjunto reducido, Lasso Regression sigue siendo el mejor, pero con un MSE de 15.17 y un R² de 0.79.

# %%
cv = 10

# %%
# Linear Regression
curr_plt = visualizer.plot_learning_curve(analysis.linear_model, 'Learning Curve (Linear Regression)', data.X_poly_df, data.y, cv=cv)
visualizer.show_plot(curr_plt)

# %% [markdown]
# La curva de aprendizaje para la regresión lineal con el conjunto de datos completo muestra que el modelo se ajusta bien a los datos de entrenamiento, ya que la curva de entrenamiento (roja) es estable y cercana a 0. Sin embargo, la curva de validación (verde) comienza muy por debajo y mejora ligeramente, pero sigue indicando un alto error de generalización. Esto sugiere underfitting, donde el modelo no captura completamente las relaciones en los datos. La varianza inicial alta disminuye con más ejemplos de entrenamiento, indicando que más datos ayudan a estabilizar el modelo. En general, el modelo necesita ser más complejo para mejorar el rendimiento en el conjunto de validación.

# %%
# Ridge Regression
curr_plt = visualizer.plot_learning_curve(analysis.ridge_model, 'Learning Curve (Ridge Regression)', data.X_poly_df, data.y, cv=cv)
visualizer.show_plot(curr_plt)

# %% [markdown]
# La curva de aprendizaje de Ridge Regression muestra que el modelo se ajusta bien a los datos de entrenamiento (curva roja estable y cercana a 0), pero no generaliza bien (curva verde con alto error negativo), indicando underfitting. La varianza alta al inicio se reduce con más datos, mejorando la estabilidad del modelo. Sin embargo, la persistente diferencia entre las curvas de entrenamiento y validación sugiere que el modelo no es lo suficientemente complejo para capturar todas las relaciones en los datos. Recomendaciones: incrementar la complejidad del modelo con características adicionales, probar modelos más complejos, añadir más datos de entrenamiento y ajustar más los parámetros de regularización para mejorar el rendimiento.

# %%
# Lasso Regression
curr_plt = visualizer.plot_learning_curve(analysis.lasso_model, 'Learning Curve (Lasso Regression)', data.X_poly_df, data.y, cv=cv)
visualizer.show_plot(curr_plt)

# %% [markdown]
# La curva de aprendizaje de Lasso Regression muestra que el modelo se ajusta bien a los datos de entrenamiento (curva roja estable y cercana a 0), pero no generaliza bien (curva verde con alto error negativo), indicando underfitting. La varianza alta al inicio se reduce con más datos, mejorando la estabilidad del modelo. Sin embargo, la persistente diferencia entre las curvas de entrenamiento y validación sugiere que el modelo no es lo suficientemente complejo para capturar todas las relaciones en los datos. Se ajustarán más los parámetros de regularización para mejorar el rendimiento.

# %%
# Optimización de hiperparámetros
ridge_params = {'alpha': [0.1, 1.0, 10.0, 100.0]}
lasso_params = {'alpha': [0.01, 0.1, 1.0, 10.0]}

best_ridge_params, best_ridge_model = analysis.hyperparameter_optimization(analysis.ridge_model, ridge_params, X_train, y_train)
best_lasso_params, best_lasso_model = analysis.hyperparameter_optimization(analysis.lasso_model, lasso_params, X_train, y_train)

print('Best Ridge Params:', best_ridge_params)
print('Best Lasso Params:', best_lasso_params)

ridge_mse, ridge_r2 = analysis.evaluate_model(best_ridge_model, X_test, y_test)
lasso_mse, lasso_r2 = analysis.evaluate_model(best_lasso_model, X_test, y_test)

print('Ridge Regression - MSE:', ridge_mse, ', R2:', ridge_r2)
print('Lasso Regression - MSE:', lasso_mse, ', R2:', lasso_r2)
# Out:
# Best Ridge Params: {'alpha': 100.0}
# Best Lasso Params: {'alpha': 0.1}
# Ridge Regression - MSE: 14.011745849324823 , R2: 0.8089319104308007
# Lasso Regression - MSE: 14.487491395486858 , R2: 0.8024445109586917

# %% [markdown]
# Comparando los resultados antes y después de la optimización de hiperparámetros, observamos mejoras y deterioros. Para Ridge Regression, la optimización de alpha mejoró ligeramente el MSE (de 14.14 a 14.01) y el R² (de 0.807 a 0.809), indicando un ajuste más preciso del modelo. Sin embargo, para Lasso Regression, la optimización resultó en un aumento del MSE (de 12.78 a 14.48) y una disminución del R² (de 0.826 a 0.802), sugiriendo que los parámetros por defecto eran más adecuados. Esto resalta que, mientras la optimización de hiperparámetros puede mejorar algunos modelos, no siempre es beneficiosa para todos.

# %%
# Ridge Regression
curr_plt = visualizer.plot_learning_curve(best_ridge_model, 'Learning Curve (Ridge Regression)', data.X_poly_df, data.y, cv=cv)
visualizer.show_plot(curr_plt)

# Lasso Regression
curr_plt = visualizer.plot_learning_curve(best_lasso_model, 'Learning Curve (Lasso Regression)', data.X_poly_df, data.y, cv=cv)
visualizer.show_plot(curr_plt)
